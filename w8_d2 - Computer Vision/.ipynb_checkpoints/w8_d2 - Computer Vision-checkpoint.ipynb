# %% [markdown]
# # Computer Vision

# %%
# Captura por webcam y region de interes

# %%
import numpy as np
import cv2

# %%
# captura webcam

def captura():
    cam=cv2.VideoCapture(0)
    while 1:
        ret, frame=cam.read()
        cv2.imshow('Captura', frame)
        
        if ret==False: break
        
        key=cv2.waitKey(1)
        
        if key%256==27: break # tecla ESC
        
        elif key%256==32: # SPACE
            img_name='captura.png'
            cv2.imwrite(img_name, frame)
            print ('Captura guardada')
            break
            
    cam.release()
    cv2.destroyAllWindows()

# %%
def contraste(): # pasa a blanco y negro puro
    image=cv2.imread('captura.png')
    im=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    im=(255-im)
    umbral=170
    
    img=np.zeros(shape=im.shape)
    for i in range(im.shape[0]):
        for j in range(im.shape[1]):
            if im[i][j]>umbral: img[i][j]=255
            else: img[i][j]=0
    
    cv2.imshow('img', img)
    cv2.imwrite('b&w.png', img)
    cv2.waitKey(0)

# %%
def contorno(): # regiones de interes
    umbral_fino=10
    image=cv2.imread('b&w.png')
    im=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    im=(255-im)
    thresh=cv2.adaptiveThreshold(im, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                 cv2.THRESH_BINARY_INV, 11, 2)
    rect_kernel=cv2.getStructuringElement(cv2.MORPH_RECT, (30,10))
    
    threshed=cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, rect_kernel)
    
    contorno,_=cv2.findContours(threshed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    s_contorno=sorted(contorno, key=lambda x: cv2.boundingRect(x)[1]+cv2.boundingRect(x)[0]*image.shape[1])
    
    idx=0
    for cut in s_contorno:
        idx+=1
        x,y,w,h=cv2.boundingRect(cut)
        roi=im[y:y+h, x:x+w]
        
        if h<umbral_fino or w<umbral_fino: continue
            
        cv2.imwrite(str(idx)+'.png', roi)
        cv2.rectangle(im, (x,y), (x+w, y+h), (200, 0, 0), 2)
        
        cv2.imshow('Imagen B-N', im)
        cv2.waitKey(0)
    
    return idx

# %%
captura()
contraste()
print (contorno())
# Out:
# Captura guardada
# <function contorno at 0x10e05a3b0>

# %%
contorno()

# %%
captura()
# Out:
# Captura guardada

# %%
# Pintando

img=cv2.imread('captura.png')

H=img.shape[0]
W=img.shape[1]

cv2.line(img, (W//2, 0), (W//2, H), (255, 255, 255), 15)
cv2.circle(img, (W//2, H//2), 512, (0,0,255), 10)

cv2.imshow('pinturas', img)
cv2.resizeWindow('pinturas', 600, 600)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# mezclar imagenes

img1=cv2.imread('captura.png', cv2.IMREAD_COLOR)
img2=cv2.imread('b&w.png', cv2.IMREAD_COLOR)

img2=cv2.resize(img2, img1.shape[:2][::-1], interpolation=cv2.INTER_AREA)

# %%
cv2.imshow('adicion', cv2.add(img1, img2))
cv2.resizeWindow('adicion', 600, 600)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Reconocimiento facial

# %%
import os
import matplotlib.pyplot as plt
import glob
import pandas as pd

images={}

for e in glob.glob('./fotos_alumnos/**/*.JPG'):
    alumno=e.split('/')[2]
    foto=e.split('/')[3]
    
    img=cv2.imread(e)
    
    print ('Read"{}" -> {}'.format(alumno, foto))
    gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    if alumno in images:
        images[alumno]['images'].append(gray)
        images[alumno]['name'].append(e)
    else:
        images[alumno]={'images':[gray], 'name':[e]}
# Out:
# Read"Santiago" -> 4.JPG
# Read"Santiago" -> 5.JPG
# Read"Santiago" -> 6.JPG
# Read"Santiago" -> 2.JPG
# Read"Santiago" -> 3.JPG
# Read"Santiago" -> 1.JPG
# Read"Javier" -> 4.JPG
# Read"Javier" -> 5.JPG
# Read"Javier" -> 6.JPG
# Read"Javier" -> 2.JPG
# Read"Javier" -> 3.JPG
# Read"Javier" -> 1.JPG
# Read"Reynaldo" -> 4.JPG
# Read"Reynaldo" -> 5.JPG
# Read"Reynaldo" -> 6.JPG
# Read"Reynaldo" -> 2.JPG
# Read"Reynaldo" -> 3.JPG
# Read"Reynaldo" -> 1.JPG
# Read"Luis" -> 4.JPG
# Read"Luis" -> 5.JPG
# Read"Luis" -> 6.JPG
# Read"Luis" -> 2.JPG
# Read"Luis" -> 3.JPG
# Read"Luis" -> 1.JPG
# Read"Jorge" -> 4.JPG
# Read"Jorge" -> 5.JPG
# Read"Jorge" -> 6.JPG
# Read"Jorge" -> 2.JPG
# Read"Jorge" -> 3.JPG
# Read"Jorge" -> 1.JPG
# Read"Valeria" -> 4.JPG
# Read"Valeria" -> 5.JPG
# Read"Valeria" -> 6.JPG
# Read"Valeria" -> 2.JPG
# Read"Valeria" -> 3.JPG
# Read"Valeria" -> 1.JPG
# Read"Ernesto" -> 4.JPG
# Read"Ernesto" -> 5.JPG
# Read"Ernesto" -> 6.JPG
# Read"Ernesto" -> 2.JPG
# Read"Ernesto" -> 3.JPG
# Read"Ernesto" -> 1.JPG
# Read"Enrique" -> 4.JPG
# Read"Enrique" -> 5.JPG
# Read"Enrique" -> 6.JPG
# Read"Enrique" -> 2.JPG
# Read"Enrique" -> 3.JPG
# Read"Enrique" -> 1.JPG
# Read"Roger" -> 4.JPG
# Read"Roger" -> 5.JPG
# Read"Roger" -> 6.JPG
# Read"Roger" -> 2.JPG
# Read"Roger" -> 3.JPG
# Read"Roger" -> 1.JPG
# Read"Diego_F" -> 4.JPG
# Read"Diego_F" -> 5.JPG
# Read"Diego_F" -> 6.JPG
# Read"Diego_F" -> 2.JPG
# Read"Diego_F" -> 3.JPG
# Read"Diego_F" -> 1.JPG
# Read"Diego_R" -> 4.JPG
# Read"Diego_R" -> 5.JPG
# Read"Diego_R" -> 6.JPG
# Read"Diego_R" -> 2.JPG
# Read"Diego_R" -> 3.JPG
# Read"Diego_R" -> 1.JPG
# Read"Ivan" -> 4.JPG
# Read"Ivan" -> 5.JPG
# Read"Ivan" -> 6.JPG
# Read"Ivan" -> 2.JPG
# Read"Ivan" -> 3.JPG
# Read"Ivan" -> 1.JPG
# Read"Paco" -> 4.JPG
# Read"Paco" -> 5.JPG
# Read"Paco" -> 6.JPG
# Read"Paco" -> 2.JPG
# Read"Paco" -> 3.JPG
# Read"Paco" -> 1.JPG
# Read"Raul" -> 4.JPG
# Read"Raul" -> 5.JPG
# Read"Raul" -> 6.JPG
# Read"Raul" -> 2.JPG
# Read"Raul" -> 3.JPG
# Read"Raul" -> 1.JPG

# %%
list(map(lambda x: x[0], images.items()))
# Out:
# ['Santiago',
#  'Javier',
#  'Reynaldo',
#  'Luis',
#  'Jorge',
#  'Valeria',
#  'Ernesto',
#  'Enrique',
#  'Roger',
#  'Diego_F',
#  'Diego_R',
#  'Ivan',
#  'Paco',
#  'Raul']

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

# %%
imgs=images['Reynaldo']['images']

plt.figure(figsize=(10,10))
for i,e in enumerate(imgs):
    img=e.copy()
    faces=face_cascade.detectMultiScale(img, 1.1, 4)
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 4)
        break
    plt.subplot(2,2,i+1)
    (x,y,w,h)=faces[0]
    crop=img[y:y+h, x:x+w]
    plt.imshow(crop, cmap='gray')
    if i>=3: break

# %%
for alumno, data in images.items():
    for i,e in enumerate(data['images']):
        img=e.copy()
        faces=face_cascade.detectMultiScale(img, 1.1, 4)
        (x,y,w,h)=faces[0]
        crop=img[y:y+h, x:x+w]
        
        if 'crops' in images[alumno]:
            images[alumno]['crops'].append(crop)
        else:
            images[alumno]['crops']=[crop]
        
        name='{}/caras/{}-{}.JPG'.format(os.getcwd(), alumno, i)
        
        print (name)
        
        cv2.imwrite(name, crop)
# Out:
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Santiago-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Javier-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Reynaldo-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Luis-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Jorge-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Valeria-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ernesto-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Enrique-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Roger-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_F-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Diego_R-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Ivan-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Paco-5.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-0.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-1.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-2.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-3.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-4.JPG
# /Users/data/Desktop/clases_datamex1019/w8_d2 - Computer Vision/caras/Raul-5.JPG

# %%
def features(img, n_f=40):
    fft=np.log10(np.abs(np.fft.fft2(img)))
    w=fft.shape[0]//2
    fft=fft[0:w, 0:w]
    feats=fft[:n_f, :n_f]
    return np.hstack(feats)

# %%
datacols=[]
for alumno, data in images.items():
    for crop,name in zip(data['crops'], data['name']):
        X_alu=features(crop)
        datacols.append({'alumno':alumno, 'foto':name, 'features':X_alu})

# %%
df=pd.DataFrame(datacols)
df.head()
# Out:
#      alumno                            foto  \
# 0  Santiago  ./fotos_alumnos/Santiago/4.JPG
# 1  Santiago  ./fotos_alumnos/Santiago/5.JPG
# 2  Santiago  ./fotos_alumnos/Santiago/6.JPG
# 3  Santiago  ./fotos_alumnos/Santiago/2.JPG
# 4  Santiago  ./fotos_alumnos/Santiago/3.JPG
#
#                                             features
# 0  [7.99654339813354, 6.929112559448951, 6.779876...
# 1  [7.951829547258093, 6.875774127904844, 6.88473...
# 2  [7.99654339813354, 6.929112559448951, 6.779876...
# 3  [7.94242323360106, 6.99307355148248, 7.0159144...
# 4  [7.902751072517425, 6.846940586273853, 6.92141...

# %%
X_test=df.groupby('alumno').nth(0).reset_index()
X_train=df[~df['foto'].isin(X_test['foto'])].reset_index()

# %%
preds=[]

for e in X_test.index:
    X_miss=X_test.iloc[e]['features']
    X_miss_name=X_test.iloc[e]['alumno']
    X_data=X_train['features']
    
    dist=[]
    
    for i,e in X_data.items():
        if e.shape==X_miss.shape:
            d=np.linalg.norm(e-X_miss)
            dist.append((int(i), d))
    
    sorted_d=pd.DataFrame(dist, columns=['index', 'distance']).sort_values(by='distance')
    w_idx=int(sorted_d.iloc[0].values[0])
    p=X_train.iloc[w_idx]['alumno']
    preds.append([X_miss_name, p])

# %%
pd.DataFrame(preds, columns=['real', 'prediccion'])
# Out:
#         real prediccion
# 0    Diego_F    Diego_R
# 1    Diego_R    Ernesto
# 2    Enrique     Javier
# 3    Ernesto    Ernesto
# 4       Ivan       Ivan
# 5     Javier     Javier
# 6      Jorge      Jorge
# 7       Luis       Luis
# 8       Paco    Diego_R
# 9       Raul   Santiago
# 10  Reynaldo    Valeria
# 11     Roger      Roger
# 12  Santiago   Santiago
# 13   Valeria       Luis

# %% [markdown]
# # Deteccion de objetos

# %%
THRESHOLD=0.8

# %%
class_names = {0: 'background',
              1: 'person', 2: 'bicycle', 3: 'car', 4: 'motorcycle', 5: 'airplane', 6: 'bus',
              7: 'train', 8: 'truck', 9: 'boat', 10: 'traffic light', 11: 'fire hydrant',
              13: 'stop sign', 14: 'parking meter', 15: 'bench', 
               16: 'bird', 17: 'cat',
              18: 'dog', 19: 'horse', 20: 'sheep', 21: 'cow', 22: 'elephant', 23: 'bear',
              24: 'zebra', 25: 'giraffe', 27: 'backpack', 28: 'umbrella', 31: 'handbag',
              32: 'tie', 33: 'suitcase', 
               34: 'frisbee', 35: 'skis', 36: 'snowboard',
              37: 'sports ball', 38: 'kite', 39: 'baseball bat', 40: 'baseball glove',
              41: 'skateboard', 42: 'surfboard', 43: 'tennis racket', 44: 'bottle',
              46: 'wine glass', 47: 'cup', 48: 'fork', 49: 'knife', 50: 'spoon',
              51: 'bowl', 52: 'banana', 53: 'apple', 54: 'sandwich', 55: 'orange',
              56: 'broccoli', 57: 'carrot', 58: 'hot dog', 59: 'pizza', 60: 'donut',
              61: 'cake', 62: 'chair', 
               63: 'couch', 64: 'potted plant', 65: 'bed',
              67: 'dining table', 70: 'toilet', 72: 'tv', 73: 'laptop', 74: 'mouse',
              75: 'remote', 76: 'keyboard', 77: 'cell phone', 78: 'microwave', 79: 'oven',
              80: 'toaster', 81: 'sink', 82: 'refrigerator', 84: 'book', 85: 'clock',
              86: 'vase', 87: 'scissors', 88: 'teddy bear', 89: 'hair drier', 90: 'toothbrush'}
