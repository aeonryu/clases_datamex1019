# %%
from selenium import webdriver

# %%
navegador = webdriver.Chrome()

# %%
navegador.get('https://www.overbuff.com')

# %%
navegador.find_element_by_xpath('/html/body/div[1]/div[1]/div[1]/div/div[2]/a').click()

# %%
tabla = navegador.find_element_by_tag_name('table')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6dad502825dcafa3606f2f5bc47f4337", element="2e655093-8fbd-4590-8cf7-a5f036b7d798")>

# %%
tabla_encabezado = tabla.find_element_by_tag_name('thead')
tabla_encabe
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6dad502825dcafa3606f2f5bc47f4337", element="85654d31-c9bb-4cc8-b537-d300db28000f")>

# %%
columnas = tabla_encabezado.find_element_by_tag_name('tr')
columnas.
# Out:
# 'Hero Pick Rate Win Rate Tie Rate On Fire'

# %%
tbody= navegador.find_element_by_tag_name('tbody')

# %%
tr_body = navegador.find_elements_by_tag_name('tr')

# %%
tr = [i.text for i in tr_body]
tr_complete= tr[1:]

# %%
tr_clean= [i.split('\n')for i in tr_complete]
tr_clean
# Out:
# [['Moira', 'SUPPORT', '12.65%', '51.50%', '2.59%', '13.93%'],
#  ['Ana', 'SUPPORT', '7.21%', '48.83%', '2.38%', '10.31%'],
#  ['Reinhardt', 'TANK', '7.01%', '50.80%', '2.58%', '7.94%'],
#  ['Orisa', 'TANK', '6.39%', '52.79%', '2.65%', '8.44%'],
#  ['Mercy', 'SUPPORT', '5.77%', '49.80%', '2.64%', '2.28%'],
#  ['Lúcio', 'SUPPORT', '5.25%', '52.12%', '2.38%', '13.01%'],
#  ['Sigma', 'TANK', '5.13%', '51.38%', '2.59%', '13.61%'],
#  ['Zarya', 'TANK', '4.99%', '51.21%', '2.43%', '11.53%'],
#  ['McCree', 'OFFENSE', '4.60%', '48.60%', '2.11%', '11.46%'],
#  ['Roadhog', 'TANK', '4.55%', '50.78%', '2.24%', '9.90%'],
#  ['Reaper', 'OFFENSE', '3.66%', '51.62%', '2.39%', '15.72%'],
#  ['Doomfist', 'OFFENSE', '3.49%', '50.80%', '2.17%', '8.14%'],
#  ['Wrecking Ball', 'TANK', '2.75%', '49.94%', '2.25%', '3.45%'],
#  ['Hanzo', 'DEFENSE', '2.68%', '49.61%', '2.30%', '12.62%'],
#  ['Baptiste', 'SUPPORT', '2.49%', '48.25%', '3.04%', '12.51%'],
#  ['Genji', 'OFFENSE', '2.34%', '48.50%', '2.18%', '11.11%'],
#  ['Junkrat', 'DEFENSE', '1.98%', '50.92%', '2.77%', '11.57%'],
#  ['Ashe', 'OFFENSE', '1.86%', '52.19%', '2.26%', '9.43%'],
#  ['Widowmaker', 'DEFENSE', '1.68%', '50.53%', '1.93%', '7.70%'],
#  ['Mei', 'DEFENSE', '1.65%', '52.42%', '2.63%', '10.65%'],
#  ['Winston', 'TANK', '1.56%', '47.41%', '2.21%', '6.57%'],
#  ['Tracer', 'OFFENSE', '1.54%', '48.75%', '2.06%', '7.52%'],
#  ['D.Va', 'TANK', '1.51%', '48.25%', '2.30%', '6.65%'],
#  ['Zenyatta', 'SUPPORT', '1.34%', '51.53%', '2.13%', '8.24%'],
#  ['Pharah', 'OFFENSE', '1.34%', '50.31%', '2.21%', '11.99%'],
#  ['Brigitte', 'SUPPORT', '1.07%', '57.07%', '2.14%', '10.43%'],
#  ['Symmetra', 'SUPPORT', '1.07%', '54.56%', '3.55%', '9.60%'],
#  ['Soldier: 76', 'OFFENSE', '0.91%', '48.30%', '2.18%', '9.78%'],
#  ['Sombra', 'OFFENSE', '0.61%', '45.98%', '2.31%', '13.02%'],
#  ['Bastion', 'DEFENSE', '0.53%', '51.16%', '2.91%', '18.70%'],
#  ['Torbjörn', 'DEFENSE', '0.40%', '56.54%', '2.73%', '8.49%']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(tr_clean, columns= (['Hero', 'Position', 'Pick Rate', 'Win Rate', 'Tie Rate', 'On Fire']))

# %%
df
# Out:
#              Hero Position Pick Rate Win Rate Tie Rate On Fire
# 0           Moira  SUPPORT    12.65%   51.50%    2.59%  13.93%
# 1             Ana  SUPPORT     7.21%   48.83%    2.38%  10.31%
# 2       Reinhardt     TANK     7.01%   50.80%    2.58%   7.94%
# 3           Orisa     TANK     6.39%   52.79%    2.65%   8.44%
# 4           Mercy  SUPPORT     5.77%   49.80%    2.64%   2.28%
# 5           Lúcio  SUPPORT     5.25%   52.12%    2.38%  13.01%
# 6           Sigma     TANK     5.13%   51.38%    2.59%  13.61%
# 7           Zarya     TANK     4.99%   51.21%    2.43%  11.53%
# 8          McCree  OFFENSE     4.60%   48.60%    2.11%  11.46%
# 9         Roadhog     TANK     4.55%   50.78%    2.24%   9.90%
# 10         Reaper  OFFENSE     3.66%   51.62%    2.39%  15.72%
# 11       Doomfist  OFFENSE     3.49%   50.80%    2.17%   8.14%
# 12  Wrecking Ball     TANK     2.75%   49.94%    2.25%   3.45%
# 13          Hanzo  DEFENSE     2.68%   49.61%    2.30%  12.62%
# 14       Baptiste  SUPPORT     2.49%   48.25%    3.04%  12.51%
# 15          Genji  OFFENSE     2.34%   48.50%    2.18%  11.11%
# 16        Junkrat  DEFENSE     1.98%   50.92%    2.77%  11.57%
# 17           Ashe  OFFENSE     1.86%   52.19%    2.26%   9.43%
# 18     Widowmaker  DEFENSE     1.68%   50.53%    1.93%   7.70%
# 19            Mei  DEFENSE     1.65%   52.42%    2.63%  10.65%
# 20        Winston     TANK     1.56%   47.41%    2.21%   6.57%
# 21         Tracer  OFFENSE     1.54%   48.75%    2.06%   7.52%
# 22           D.Va     TANK     1.51%   48.25%    2.30%   6.65%
# 23       Zenyatta  SUPPORT     1.34%   51.53%    2.13%   8.24%
# 24         Pharah  OFFENSE     1.34%   50.31%    2.21%  11.99%
# 25       Brigitte  SUPPORT     1.07%   57.07%    2.14%  10.43%
# 26       Symmetra  SUPPORT     1.07%   54.56%    3.55%   9.60%
# 27    Soldier: 76  OFFENSE     0.91%   48.30%    2.18%   9.78%
# 28         Sombra  OFFENSE     0.61%   45.98%    2.31%  13.02%
# 29        Bastion  DEFENSE     0.53%   51.16%    2.91%  18.70%
# 30       Torbjörn  DEFENSE     0.40%   56.54%    2.73%   8.49%

# %%
for i in tr_clean:
    df =  df.append(i)
    
df
# Out:
# C:\Users\Sativa\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
